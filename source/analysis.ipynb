# %%
import seaborn as sn
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
from game import run_game

# %%
l = [run_game(5) for i in range(100000)]
sn.kdeplot(l)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
l = [run_game(56) for i in range(100000)]
sn.kdeplot(l)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
l = [run_game(568) for i in range(100000)]
sn.kdeplot(l)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
l = [run_game(11565) for i in range(100000)]
sn.kdeplot(l)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
m = []
for j in tqdm(range(200)):
    l = [run_game(10 * (j+1)) for i in range(100000)]
    k = (sum([i < 20 for i in l]) / 100000) * 100
    m.append(k)
plt.plot(m)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
